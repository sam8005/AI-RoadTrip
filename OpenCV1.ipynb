# %% [markdown]
# <a href="https://colab.research.google.com/github/GouthamSurendran/AI-RoadTrip/blob/master/OpenCV1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv
from google.colab import files 
import imutils

# %%
from google.colab.patches import cv2_imshow

# %%
uploaded = files.upload()

#img = cv2.imread('dog.jpg') 
#img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#plt.imshow(img_cvt)
#plt.show()
# Out:
#      <input type="file" id="files-d8b8b8ac-6731-48a0-9c12-eef6d2f32c5f" name="files[]" multiple disabled />
#      <output id="result-d8b8b8ac-6731-48a0-9c12-eef6d2f32c5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dog.jpg to dog (1).jpg

# %%
image = cv2.imread('dog.jpg')
img_cvt=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
(h,w,d) = image.shape
print("width={},height={},depth={}".format(w,h,d))
# Out:
# width=1680,height=1050,depth=3

# %%
(B, G, R) = image[75, 200]
print("R={}, G={}, B={}".format(R, G, B))
# Out:
# R=74, G=64, B=62

# %%
plt.imshow(img_cvt)
plt.show()

# %%
roi = image[0:250,0:350]
cv2_imshow(roi)
#cv2_waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=350x250 at 0x7FF86547C7F0>
