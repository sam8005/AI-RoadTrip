# %% [markdown]
# <a href="https://colab.research.google.com/github/GouthamSurendran/AI-RoadTrip/blob/master/TAG1ImageProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab import files 
import imutils

# %%
from google.colab.patches import cv2_imshow

# %%
uploaded = files.upload()

#img = cv2.imread('dog.jpg') 
#img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#plt.imshow(img_cvt)
#plt.show()
# Out:
#      <input type="file" id="files-a1ec9d5e-5e2e-4ea7-883c-07771cb86235" name="files[]" multiple disabled />
#      <output id="result-a1ec9d5e-5e2e-4ea7-883c-07771cb86235">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dog.jpg to dog.jpg

# %%
image = cv2.imread('dog.jpg')
img_cvt=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
(h,w,d) = image.shape
print("width={},height={},depth={}".format(w,h,d))
# Out:
# width=1680,height=1050,depth=3

# %%
(B, G, R) = image[75, 200]
print("R={}, G={}, B={}".format(R, G, B))
# Out:
# R=74, G=64, B=62

# %%
plt.imshow(img_cvt)
plt.show()

# %%
roi = image[0:250,0:350]
cv2_imshow(roi)
#cv2_waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=350x250 at 0x7FDA654405C0>

# %%
r = 300/w
dim = (300,int(h*r))
resized = cv2.resize(image,dim)
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=300x187 at 0x7FDA613BCFD0>
